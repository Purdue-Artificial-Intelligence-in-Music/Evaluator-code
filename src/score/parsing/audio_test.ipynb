# %%
from music21 import *
import math
import os
import time
import numpy
import wave

# %%
#import wave file
file = 'wav/four_a_notes.wav'
p = audioSearch.transcriber.monophonicStreamFromFile(file)
# Out:
# c:\Users\thebo\miniconda3\envs\AIM\Lib\site-packages\music21\audioSearch\__init__.py:148: UserWarning: Running convolve without scipy -- will be slower
#   warnings.warn('Running convolve without scipy -- will be slower')
# c:\Users\thebo\miniconda3\envs\AIM\Lib\site-packages\music21\audioSearch\__init__.py:237: RuntimeWarning: overflow encountered in scalar subtract
#   vertex = (correlation[peak - 1] - correlation[peak + 1]) / (
# c:\Users\thebo\miniconda3\envs\AIM\Lib\site-packages\music21\audioSearch\__init__.py:148: UserWarning: Running convolve without scipy -- will be slower
#   warnings.warn('Running convolve without scipy -- will be slower')
# c:\Users\thebo\miniconda3\envs\AIM\Lib\site-packages\music21\audioSearch\__init__.py:148: UserWarning: Running convolve without scipy -- will be slower
#   warnings.warn('Running convolve without scipy -- will be slower')
# ...
